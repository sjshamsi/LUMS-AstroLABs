# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.style.use('seaborn')
plt.style.use('seaborn-colorblind')

# %%
data = pd.read_excel('AM0AM1_5.xls', header=1)
data = data[data['Wavelength (nm)'] < 1400]
data
# Out:
#       Wavelength (nm)  Extraterrestrial W*m-2*nm-1  Global tilt  W*m-2*nm-1  \
# 0               280.0                      0.08200             4.730900e-23
# 1               280.5                      0.09900             1.230700e-21
# 2               281.0                      0.15000             5.689500e-21
# 3               281.5                      0.21200             1.566200e-19
# 4               282.0                      0.26700             1.194600e-18
# ...               ...                          ...                      ...
# 1235           1395.0                      0.34754             6.713600e-07
# 1236           1396.0                      0.34943             6.321500e-09
# 1237           1397.0                      0.34932             4.905700e-05
# 1238           1398.0                      0.34952             1.270400e-03
# 1239           1399.0                      0.34886             8.122600e-04
#
#       Direct+circumsolar W*m-2*nm-1  Unnamed: 4  Wavelength (nm).1  W*m-2*nm-1
# 0                      2.536100e-26         NaN              119.5    0.000062
# 1                      1.091700e-24         NaN              120.5    0.000561
# 2                      6.125300e-24         NaN              121.5    0.004901
# 3                      2.747900e-22         NaN              122.5    0.001184
# 4                      2.834600e-21         NaN              123.5    0.000048
# ...                             ...         ...                ...         ...
# 1235                   6.513700e-07         NaN             2078.0    0.100000
# 1236                   6.133800e-09         NaN             2080.0    0.098780
# 1237                   4.760500e-05         NaN             2082.0    0.098640
# 1238                   1.232900e-03         NaN             2084.0    0.097720
# 1239                   7.883500e-04         NaN             2086.0    0.098520
#
# [1240 rows x 7 columns]

# %%
wavlens1 = data['Wavelength (nm)']
ext = data['Extraterrestrial W*m-2*nm-1']
global_tilt = data['Global tilt  W*m-2*nm-1']
d_s = data['Direct+circumsolar W*m-2*nm-1']

wavlens2 = data['Wavelength (nm).1']
irr2 = data['W*m-2*nm-1']

# %%
plt.figure(figsize=(16, 10))

plt.plot(wavlens1, ext, linewidth=0.8, label='Extraterrestrial')
plt.plot(wavlens1, global_tilt, linewidth=0.8, label='Global Tilt')
plt.plot(wavlens1, d_s, linewidth=0.8, label='Direct + Circumsolar')

plt.plot(wavlens2, irr2, linewidth=0.8, label='ASTM E-490 AM0 Standard Spectra')

plt.xlim(300, 1400)

plt.xlabel('Wavelength $\\lambda$', size=20, labelpad=20)
plt.ylabel('Spectral Emissison $W m^{-2} nm^{-1}$', size=20, labelpad=20)

plt.xticks(np.arange(300, 1400, 50), size=15)
plt.yticks(size=15)

plt.legend(fontsize=16)
